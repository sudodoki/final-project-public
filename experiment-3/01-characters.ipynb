# %%
import os
import re

import pandas as pd
import numpy as np

import books_utils as bu

# %%
annotations = pd.read_csv('../data/character_relation_annotations.txt.gz', sep='\t')
# dropping values that have gibberish affinity - might transform this later based on category
annotations = annotations[(annotations['affinity'] != 'NR') & (annotations['character_1'] != 'NR') & (annotations['character_2'] != 'NR')].copy()
annotations['book_name'] = (annotations['title'] + ' ' + annotations['author']).str.replace("\s", "_")
print(annotations.shape)
# making sure no NR in character_1/character_2/affinity
annotations.describe()
# Out:
# (2137, 11)
#           annotator change    title               author character_1  \
# count          2137   2137     2137                 2137        2137
# unique           14      3      109                   49        1005
# top     annotator_1     no  Othello  William Shakespeare   Joseph K.
# freq            760   1712       20                  613          15
#
#        character_2  affinity coarse_category fine_category detail  \
# count         2137      2137            2137          2137   2137
# unique         825         3               4            30    528
# top          Timon  positive          social        friend     NR
# freq            17      1120             886           342   1591
#
#                                           book_name
# count                                          2137
# unique                                          109
# top     The_Taming_of_the_Shrew_William_Shakespeare
# freq                                             20

# %%
annotations.head(1)
# Out:
#      annotator change        title               author   character_1  \
# 0  annotator_1    yes  Don Quixote  Miguel de Cervantes  Sancho Panza
#
#    character_2  affinity coarse_category fine_category  \
# 0  Don Quixote  positive    professional       servant
#
#                                               detail  \
# 0  he ends up taking more authority and advising ...
#
#                          book_name
# 0  Don_Quixote_Miguel_de_Cervantes

# %%
np.unique(annotations[annotations['book_name'] == 'Don_Quixote_Miguel_de_Cervantes'][['character_1', 'character_2']].values)
# Out:
# array(['Altisidora', 'Cervantes', 'Cide Hamete Benengeli', 'Dapple',
#        'Don Quixote', 'Dulcinea del Toboso', 'Rocinante',
#        'Sampson Carrasco', 'Sancho Panza', 'The Duke and Duchess',
#        'The barber', 'The priest'], dtype=object)

# %%
annotations[(annotations['character_1'].str.contains(' and ')) | (annotations['character_2'].str.contains(' and '))| (annotations['character_1'].str.contains(';')) | (annotations['character_2'].str.contains(';'))]
# Out:
#          annotator change                    title               author  \
# 4      annotator_1     no              Don Quixote  Miguel de Cervantes
# 5      annotator_1     no              Don Quixote  Miguel de Cervantes
# 7      annotator_1     no              Don Quixote  Miguel de Cervantes
# 14     annotator_2     no              Don Quixote  Miguel de Cervantes
# 15     annotator_2     no              Don Quixote  Miguel de Cervantes
# 16     annotator_2     no              Don Quixote  Miguel de Cervantes
# 119    annotator_1     no               Richard II  William Shakespeare
# 552   annotator_10     no          Henry IV Part 2  William Shakespeare
# 553   annotator_10     no          Henry IV Part 2  William Shakespeare
# 558   annotator_10    yes          Henry IV Part 2  William Shakespeare
# 618    annotator_2     no                  Ulysses          James Joyce
# 888    annotator_5    yes      Pride and Prejudice          Jane Austen
# 1217   annotator_4     no       The House of Mirth        Edith Wharton
# 1296   annotator_3     NR                   Hamlet  William Shakespeare
# 1297   annotator_3     NR                   Hamlet  William Shakespeare
# 1459   annotator_2    yes            Sister Carrie     Theodore Dreiser
# 1465   annotator_4    yes            Sister Carrie     Theodore Dreiser
# 1488   annotator_5     no         Northanger Abbey          Jane Austen
# 1536   annotator_1     no  The Taming of the Shrew  William Shakespeare
# 1537   annotator_1     no  The Taming of the Shrew  William Shakespeare
# 1546   annotator_4     no  The Taming of the Shrew  William Shakespeare
# 1549   annotator_4     no  The Taming of the Shrew  William Shakespeare
# 1688   annotator_6     no              Main Street       Sinclair Lewis
# 1772  annotator_10     no         Titus Andronicus  William Shakespeare
# 1782  annotator_11     no         Titus Andronicus  William Shakespeare
#
#                                             character_1  \
# 4                                  The Duke and Duchess
# 5                                  The Duke and Duchess
# 7                                            Altisidora
# 14                                 The Duke and Duchess
# 15                                 The Duke and Duchess
# 16                                           Altisidora
# 119   Henry Percy Earl of Northumberland; Lord Ross;...
# 552                                       King Henry IV
# 553                                       King Henry IV
# 558                     Prince Hal (later King Henry V)
# 618                  Josie (née Powell) and Denis Breen
# 888                               Mr. and Mrs. Gardiner
# 1217                      Jack Stepney and Gwen Stepney
# 1296                       Rosencrantz and Guildenstern
# 1297                            Voltimand and Cornelius
# 1459                                 Fitzgerald and Moy
# 1465                                 Fitzgerald and Moy
# 1488                                 Mr. and Mrs. Allen
# 1536                                             Bianca
# 1537                               Gremio and Hortensio
# 1546                               Gremio and Hortensio
# 1549                               Gremio and Hortensio
# 1688               Aunt Bessie and Uncle Whittier Smail
# 1772                                             Tamora
# 1782                                             Tamora
#
#                             character_2  affinity coarse_category  \
# 4                           Don Quixote  negative          social
# 5                          Sancho Panza  negative          social
# 7                  The Duke and Duchess  positive    professional
# 14                          Don Quixote   neutral          social
# 15                         Sancho Panza   neutral          social
# 16                 The Duke and Duchess   neutral    professional
# 119   Henry Bolingbroke Duke of Herford  positive    professional
# 552         Duke of Lancaster; Humphrey  positive        familial
# 553      Duke of Gloucester; and Thomas  positive        familial
# 558                Mowbray and Hastings  negative          social
# 618                       Leopold Bloom   neutral          social
# 888                    Elizabeth Bennet  positive        familial
# 1217                          Lily Bart  positive        familial
# 1296                             Hamlet  negative          social
# 1297                           Claudius  positive    professional
# 1459                   George Hurstwood  negative    professional
# 1465                   George Hurstwood  positive    professional
# 1488                  Catherine Morland  positive        familial
# 1536               Gremio and Hortensio  negative          social
# 1537                           Lucentio  negative          social
# 1546                             Bianca  negative          social
# 1549                          Petruchio  positive          social
# 1688                          Kennicott   neutral        familial
# 1772               Chiron and Demetrius  positive        familial
# 1782               Chiron and Demetrius  negative        familial
#
#                  fine_category  \
# 4                        enemy
# 5                        enemy
# 7                      servant
# 14                      rivals
# 15                      rivals
# 16                    employee
# 119                  colleague
# 552                         NR
# 553                         NR
# 558                         NR
# 618                     friend
# 888                step-parent
# 1217                    cousin
# 1296                    friend
# 1297                   servant
# 1459                  employer
# 1465                  employer
# 1488               step-parent
# 1536  unrequited love interest
# 1537                    rivals
# 1546  unrequited love interest
# 1549                    friend
# 1688                uncle/aunt
# 1772                    parent
# 1782                    parent
#
#                                                  detail  \
# 4                                                    NR
# 5                                                    NR
# 7                                                    NR
# 14                                                   NR
# 15                                                   NR
# 16                     Altisidora is The Duchess' maid.
# 119                                                  NR
# 552                                                  NR
# 553                                                  NR
# 558                                             Enemies
# 618                     Josie and Leopold used to date.
# 888   caring and better parents than Mr and Mrs. Ben...
# 1217                                                 NR
# 1296                                                 NR
# 1297                                                 NR
# 1459  George is the manage of Fitzgerald and Moy's s...
# 1465  Hurstwood employers choose not to prosecute hi...
# 1488                                                 NR
# 1536                                                 NR
# 1537                                                 NR
# 1546                                                 NR
# 1549                                                 NR
# 1688                                                 NR
# 1772                                                 NR
# 1782                                                 NR
#
#                                         book_name
# 4                 Don_Quixote_Miguel_de_Cervantes
# 5                 Don_Quixote_Miguel_de_Cervantes
# 7                 Don_Quixote_Miguel_de_Cervantes
# 14                Don_Quixote_Miguel_de_Cervantes
# 15                Don_Quixote_Miguel_de_Cervantes
# 16                Don_Quixote_Miguel_de_Cervantes
# 119                Richard_II_William_Shakespeare
# 552           Henry_IV_Part_2_William_Shakespeare
# 553           Henry_IV_Part_2_William_Shakespeare
# 558           Henry_IV_Part_2_William_Shakespeare
# 618                           Ulysses_James_Joyce
# 888               Pride_and_Prejudice_Jane_Austen
# 1217             The_House_of_Mirth_Edith_Wharton
# 1296                   Hamlet_William_Shakespeare
# 1297                   Hamlet_William_Shakespeare
# 1459               Sister_Carrie_Theodore_Dreiser
# 1465               Sister_Carrie_Theodore_Dreiser
# 1488                 Northanger_Abbey_Jane_Austen
# 1536  The_Taming_of_the_Shrew_William_Shakespeare
# 1537  The_Taming_of_the_Shrew_William_Shakespeare
# 1546  The_Taming_of_the_Shrew_William_Shakespeare
# 1549  The_Taming_of_the_Shrew_William_Shakespeare
# 1688                   Main_Street_Sinclair_Lewis
# 1772         Titus_Andronicus_William_Shakespeare
# 1782         Titus_Andronicus_William_Shakespeare

# %%
# https://git.io/vpzth
def splitDataFrameList(df,target_column,separator):
    ''' df = dataframe to split,
    target_column = the column containing the values to split
    separator = the symbol used to perform the split
    returns: a dataframe with each entry for the target column separated, with each element moved into a new row. 
    The values in the other columns are duplicated across the newly divided rows.
    '''
    row_accumulator = []

    def splitListToRows(row, separator):
        split_row = row[target_column].split(separator)
        for s in split_row:
            new_row = row.to_dict()
            # super custom hack for Mr & Mrs. case
            substitution = s
            if s.endswith('Mr.') or s.endswith('Mrs.'):
                substitution = s + ' ' + re.sub('^Mrs?\.\s?', '', split_row[-1])
            new_row[target_column] = substitution
            row_accumulator.append(new_row)

    df.apply(splitListToRows, axis=1, args = (separator, ))
    new_df = pd.DataFrame(row_accumulator)
    return new_df

new_df = splitDataFrameList(annotations, 'character_1', ' and ')
new_df = splitDataFrameList(new_df, 'character_2', ' and ')
new_df = splitDataFrameList(new_df, 'character_1', ';')
new_df = splitDataFrameList(new_df, 'character_2', ';')

# %%
existing_files = []
chars = {}
book_names = new_df['book_name'].unique()
for name in book_names:
    chars[name] = np.unique(new_df[new_df['book_name'] == name][['character_1', 'character_2']].values)
    file = '../data/books/{}.txt'.format(name)
    existing_files.append(os.path.isfile(file))
len(book_names), len(existing_files), all(existing_files)
# Out:
# (109, 109, True)

# %%
books = [bu.Book(name, book_NLP_folder="../data/bookNLP_output", source_folder="../data/books") for name in book_names]

# %%
for book in books:
    len(book.characters.all)

# %%
total = 0
no_name = 0
total_found = 0
multiple_chars = 0
mosts = [{
    'count': -1,
    'book': books[0],
    'char': ''
}]
for book in books:
    print(f'Book: {book.name}')
    for char in chars[book.name]:
        total += 1
        times_found = 0
        found = False
        print(f'{char} <- ', end = '')
        for bchar in book.characters.all:
            name_in_book = bu.book_name_to_annotated_name(book.name, bchar, [char], False)
            if name_in_book:
                times_found += 1
                if found:
                    multiple_chars += 1
                else:
                    total_found += 1
                found = True
                
                print(f'({bu.longest_name(bchar)} {bchar["id"]}), ', end='')
        if times_found > mosts[-1]['count']:
            mosts.append({
                'count': times_found,
                'book': book.name,
                'char': char
            })
        if not found:
            no_name += 1
        print('')
    print('')
print(f'Total chars annotated: {total}.\nTotal chars from annotations in books {total_found}.\nNot found: {no_name}.\nMultiple chars corresponding: {multiple_chars}')
print(mosts[1:])
# Out:
# Book: Don_Quixote_Miguel_de_Cervantes
# Altisidora <- (ALTISIDORA 65),
# Cervantes <- (Miguel de Cervantes 149),
# Cide Hamete Benengeli <- (Cide Hamete Benengeli 162),
# Dapple <- (Dapple 185),
# Don Quixote <- (Don Quixotes 25), (Senor Don Quixote 66), (lord Don Quixote 103),
# Duchess <-
# Dulcinea del Toboso <- (lady Dona Dulcinea del Toboso 247),
# Rocinante <- (Rocinante 118),
# Sampson Carrasco <- (SAMSON CARRASCO 102),
# Sancho Panza <- (Sancho Panzas 174), (Senor Don Sancho Panza 236),
# The Duke <- (Duke of Sesa 119), (Duke Ricardo 157),
# The barber <-
# The priest <-
#
# Book: Little_Women_Louisa_May_Alcott
# Amy March <- (Amy March 42),
# Aunt Carrol <- (Mrs. Carrol 84),
# Beth March <- (Beth 120),
# Florence <- (Flo 55),
# Frederick Bhaer <- (Mother Bhaer 30), (Fred Vaughn 126),
# Hannah <- (Hannah 53),
# Josephine March <- (Miss Jo 37), (Josephine 131),
# Laurie Laurence <- (Mr. Laurence 17), (Mr. Laurie 80),
# Marmee <- (Marmee 14),
# Meg March <- (Meg 113),
# Mr. Brooke <- (Mrs. John Brooke 39), (Mr. Brooke 115),
# Mr. Laurence <- (Mr. Laurence 17),
# Mr. March <- (Mr. March 9),
# Sallie Gardiner <- (Miss Sallie 70), (Sallie Gardiner 93),
#
# Book: Antony_and_Cleopatra_William_Shakespeare
# Agrippa <- (Agrippa 11),
# Antony <- (MARK ANTONY 16), (Antony Shall 22), (An Antony 24),
# Cleopatra <- (CLEOPATRA 10),
# Diomedes <-
# Dolabella <- (Dolabella 34),
# Enobarbus <-
# Marcus Aemilius Lepidus <- (Lepidus 23),
# Menas <-
# Octavia <- (Octavia 43),
# Octavius Caesar <- (Octavius Caesar 6), (Julius Caesar 18),
# Pompey <- (Pompey 39),
# Proculeius <- (Proculeius 13),
# The Soothsayer <-
# Ventidius <- (Ventidius 9),
#
# Book: Sense_and_Sensibility_Jane_Austen
# Colonel Brandon <- (Mrs. Brandon 18),
# Edward Ferrars <- (Mr. Edward Ferrars 53),
# Elinor Dashwood <- (-- Elinor 8), (Marianne Dashwood 34),
# Fanny Dashwood <- (Marianne Dashwood 34), (Fanny 45),
# Henry Dashwood <- (Mr. Henry Dashwood 22), (Marianne Dashwood 34),
# John Dashwood <- (Mrs. John Dashwood 3), (Marianne Dashwood 34), (Mr. John Dashwood 54),
# Lucy Steele <- (Miss Lucy Steele 0),
# Margaret Dashwood <- (Margaret 15), (Marianne Dashwood 34),
# Marianne Dashwood <- (Marianne Dashwood 34),
# Mrs. Dashwood <- (Mrs. John Dashwood 3), (Marianne Dashwood 34),
# Sir John Middleton <- (Mrs. John Dashwood 3), (John Middleton 36), (Lady Middleton 50),
#
# Book: Henry_VIII_William_Shakespeare
# Abergavenny <-
# Anne Bullen <- (Anne Bullen 31),
# Buckingham <-
# Butts <-
# Capucius <-
# Cardinal Wolsey <- (Lord Cardinal 3), (Wolsey 6),
# Cranmer <- (Cranmer 32),
# Cromwell <- (Cromwell 33),
# Gardiner <- (Gardiner 8),
# Griffith <- (Griffith 19),
# King Henry VIII <- (Henry Guildford 4), (Henry King 9),
# Norfolk <-
# Queen Katharine <- (Katharine Queen 12),
# The child <-
#
# Book: Richard_II_William_Shakespeare
#  <-
#  Lord Ross <- (Lo 2), (Ross 20),
# Bagot <- (Bagot 31),
# Bushy <-
# Edmund of Langley Duke of York <- (DUKE OF YORK 14), (Duke of Hereford 25),
# Henry Bolingbroke Duke of Herford <- (Henry Bolingbroke 21), (Duke of Hereford 25),
# Henry Percy Earl of Northumberland <- (Harry Percy 10), (HENRY PERCY 15), (Henry Bolingbroke 21),
# John of Gaunt Duke of Lancaster <- (John of Gaunt 11), (Lancaster 16), (Duke of Hereford 25),
# King Richard II <- (KING RICHARD 8),
# Lord Willoughby <- (Lo 2), (Willoughby 9),
# The Duke of Aumerle <- (Duke of Hereford 25), (Lord Aumerle 28),
# and Green (also called Greene) <- (Green 18),
#
# Book: Lord_Jim_Joseph_Conrad
# Bugis <-
# Cornelius <- (Mr. Cornelius 12),
# Crew of the Patna <-
# Dain Waris <- (Dain Waris 39),
# Doramin <- (Doramin 31),
# Dutch-Malay woman <-
# Gentleman Brown <- (Brown 17),
# Jewel <-
# Jim <- (Lord Jim 3), (Tuan Jim 24), (Jimmy 27),
# Rajah Allang <- (Rajah Allang 44),
# Tamb'Itam <- (Tamb ' Itam 10),
#
# Book: The_Count_of_Monte_Cristo_Alexandre_Dumas
# Abbé Faria <- (Abbe Faria 4),
# Ali Pacha <- (Ali Baba 93),
# Baron Danglars <- (Baron Danglars 33), (M. Danglars 240),
# Caderousse <- (M. Caderousse 170), (Gaspard Caderousse 197),
# Edmond Dantès <- (Edmond Dantes 223),
# Fernand Mondego <- (M. Fernand Mondego 38),
# Gérard de Villefort <- (M. Noirtier de Villefort 112),
# Haydée <-
# Jacopo <- (Jacopo Manfredi 172),
# Mercédès <-
# Monsieur Morrel <- (M. Maximilian Morrel 52), (Monsieur Baptistin 100), (Monsieur Morrel 221), (Monsieur de Morcerf 226),
#
# Book: The_House_of_the_Seven_Gables_Nathaniel_Hawthorne
# Alice Pyncheon <- (Clifford Pyncheon 21), (ALICE PYNCHEON 28), (Miss Hepzibah Pyncheon 31),
# An old gentleman <-
# Clifford Pyncheon <- (Clifford Pyncheon 21), (Miss Hepzibah Pyncheon 31),
# Colonel Pyncheon <- (Clifford Pyncheon 21), (Miss Hepzibah Pyncheon 31),
# Gervayse Pyncheon <- (Clifford Pyncheon 21), (Gervayse Pyncheon 26), (Miss Hepzibah Pyncheon 31),
# Hepzibah Pyncheon <- (Clifford Pyncheon 21), (Miss Hepzibah Pyncheon 31),
# Holgrave <- (Mr. Holgrave 18),
# Judge Jaffrey Pyncheon <- (Cousin Jaffrey 19), (Clifford Pyncheon 21), (Jaffrey Pyncheon 29), (Miss Hepzibah Pyncheon 31),
# Judge Pyncheon’s son <- (Clifford Pyncheon 21), (Miss Hepzibah Pyncheon 31),
# Matthew Maule <- (Matthew Maule 32),
# Old Jaffrey Pyncheon <- (Cousin Jaffrey 19), (Clifford Pyncheon 21), (Jaffrey Pyncheon 29), (Miss Hepzibah Pyncheon 31),
# Phoebe Pyncheon <- (Miss Phoebe Pyncheon 15), (Clifford Pyncheon 21), (Miss Hepzibah Pyncheon 31), (Cousin Phoebe 37),
# Uncle Venner <- (Uncle Venner 2),
#
# Book: Typee_Herman_Melville
# Fayaway <- (Fayaway 9),
# Jimmy <- (Jimmy 27),
# Karakoee <- (Karakoee 44),
# Kory-Kory <- (Kory-Kory 47),
# Marheyo <- (Marheyo 23),
# Marnoo <- (MARNOO 25),
# Mehevi <- (Mehevi 30),
# Mow-Mow <- (Mow-Mow 31),
# Tinor <- (Tinor 16),
# Toby <- (Toby 15),
# Tommo <- (Tom 33), (Tommo 43),
#
# Book: Timon_of_Athens_William_Shakespeare
# Alcibiades <- (ALCIBIADES 5),
# Apemantus <- (Apemantus 18),
# Flaminius <-
# Flavius <-
# Lucilius <-
# Lucius <- (Lord Lucius 6),
# Lucullus <- (Lord Lucullus 4),
# Painter <-
# Poet <-
# Sempronius <-
# Servilius <- (Servilius 17),
# Timon <- (Lord Timon 0),
# Ventidius <- (Ventidius 8),
#
# Book: The_Three_Musketeers_Alexandre_Dumas
# Aramis <- (Monsieur Aramis 113),
# Athos <- (Messieurs Athos 5), (Monsieur Athos 42),
# Cardinal Richelieu <- (de Richelieu 75), (Cardinal Richelieu 107),
# D'Artagnan <- (Monsieur d'Artagnan 29),
# George Villiers <- (GEORGE VILLIERS 94),
# King Louis XIII <- (Louis XIII 57),
# Lady de Winter <-
# Madame Bonacieux <- (MONSIEUR BONACIEUX 33), (Madame Coquenard 36), (Madame Bonacieux 92),
# Madame de Chevreuse <- (Madame Coquenard 36), (Madame Bonacieux 92), (Madame de Chevreuse 138),
# Madame de Coquenard <- (Madame Coquenard 36), (Monsieur Coquenard 83), (Madame Bonacieux 92),
# Monsieur Bonacieux <- (MONSIEUR BONACIEUX 33), (Monsieur de Treville 45), (Monsieur Aramis 113),
# Monsieur de Treville <- (M. de Treville 34), (Monsieur de Treville 45), (Monsieur Aramis 113),
# Porthos <- (Messieurs Porthos 51), (Monsieur Porthos 65),
# Queen Anne <- (Anne 88),
#
# Book: Emma_Jane_Austen
# Emma Woodhouse <- (Emma Woodhouse 15),
# Frank Churchill <- (-- Frank Churchill 6), (Mr. Frank Churchill 7),
# Harriet Smith <- (Harriet Smith 50),
# Isabella Knightley <- (Mr. John Knightley 28), (-- Isabella 56),
# Jane Fairfax <- (Miss Jane Fairfax 65),
# Miss Bates <- (Miss Bates 22),
# Mr. Elton <- (Mr. Elton 58),
# Mr. George Knightley <- (Mr. John Knightley 28), (George 31),
# Mr. Perry <- (Mr. Perry 68),
# Mr. Robert Martin <- (Mr. Robert Martin 2), (-- Robert Martin 80),
# Mr. Weston <- (Mr. Weston 40), (Mrs. Weston 46),
# Mr. Woodhouse <- (Emma Woodhouse 15), (Mr. Woodhouse 34),
# Mrs. Weston <- (Mr. Weston 40), (Mrs. Weston 46),
#
# Book: Persuasion_Jane_Austen
# Anne Elliot <- (Miss Anne Elliot 18), (William Walter Elliot 55),
# Captain Frederick Wentworth <- (Mr Wentworth 41), (Frederick Wentworth 61),
# Charles Hayter <- (Charles Hayter 1), (Mrs Charles Musgrove 43),
# Charles Musgrove <- (Charles Hayter 1), (Mrs Charles Musgrove 43),
# Elizabeth Elliot <- (Miss Anne Elliot 18), (Elizabeth 44), (William Walter Elliot 55),
# Henrietta Musgrove <- (Mrs Charles Musgrove 43), (Henrietta 59),
# Louisa Musgrove <- (Louisa Musgrove 36), (Mrs Charles Musgrove 43),
# Mary Elliot Musgrove <- (Miss Anne Elliot 18), (Mrs Charles Musgrove 43), (Mary 52), (William Walter Elliot 55),
# Mr. & Mrs. Musgrove <- (Mrs Charles Musgrove 43),
# Mr. William Elliot <- (Miss Anne Elliot 18), (William Walter Elliot 55),
# Mrs. Clay <-
# Sir Walter Elliot <- (Miss Anne Elliot 18), (William Walter Elliot 55),
#
# Book: Oliver_Twist_Charles_Dickens
# Agnes Fleming <- (Agnes Fleming 56),
# Bill Sikes <- (MR. WILLIAM SIKES 18), (Bill Sikes 35),
# Charlotte <- (Charlotte 5),
# Harry Maylie <- (HARRY MAYLIE 11),
# Monks <- (Mr. Monks 4),
# Monks’s mother <-
# Mr. Brownlow <- (MR. BROWNLOW 23),
# Mr. Bumble <- (Mr. Bumble 49),
# Mr. Leeford <-
# Mr. Losberne <- (Mr. Losberne 45),
# Mr. Sowerberry <- (Mr. Sowerberry 28),
# Mrs. Bedwin <- (Mrs. Bedwin 14),
# Mrs. Corney <- (Mrs. Corney 51),
# Mrs. Maylie <- (Mrs. Maylie 9),
# Mrs. Sowerberry <- (Mr. Sowerberry 28), (Mrs. Sowerberry 68),
# Nancy <- (MISS NANCY 24),
# Oliver Twist <- (Oliver Twist 0),
# Rose Maylie <- (Rose Maylie 27), (Miss Rose 62),
#
# Book: The_Adventures_of_Tom_Sawyer_Mark_Twain
# Amy Lawrence <- (Amy Lawrence 38),
# Aunt Polly <- (Aunt Polly 27),
# Becky Thatcher <- (Becky Thatcher 12), (Jeff Thatcher 22),
# Ben Rogers <- (Ben Rogers 33),
# Huckleberry Finn <- (Huck Finn 0), (Huckleberry Finn 36),
# Injun Joe <- (Injun Joe 16), (Joe Harper 37),
# Jim <- (Jim Hollis 32),
# Joe Harper <- (Joe Harper 37),
# Judge Thatcher <- (Becky Thatcher 12), (Jeff Thatcher 22),
# Mary <- (Mary 31),
# Muff Potter <- (Muff Potter 18),
# Sid <- (Sid 21),
# The Widow Douglas <- (Douglas 26),
# Tom Sawyer <- (Tom Sawyer 1),
#
# Book: A_Portrait_of_the_Artist_as_a_Young_Man_James_Joyce
# Dante (Mrs. Riordan) <- (Dante 44),
# Eileen Vance <- (Eileen 99),
# Emma Clery <- (Emma 12),
# Father Arnall <- (Arnall 23),
# Fleming <- (Fleming 118),
# Mary Dedalus <- (Stephen Dedalus 96), (MARY 106),
# Mike Flynn <- (Mike Flynn 50),
# Mr. John Casey <- (John Anthony Collins 104),
# Simon Dedalus <- (Simon Moonan 32), (Stephen Dedalus 96),
# Stephen Dedalus <- (Stephen Dedalus 96),
# The Dedalus Children <- (Stephen Dedalus 96),
# Uncle Charles <- (Uncle Charles 9),
# Vincent Heron <- (Vincent Heron 10),
# Wells <- (Wells 101),
#
# Book: Troilus_and_Cressida_William_Shakespeare
# Achilles <- (Achilles 15),
# Agamemnon <-
# Ajax <- (Ajax 5),
# Andromache <-
# Calchas <- (Calchas 3),
# Cressida <- (lady Cressid 19), (Lady Cressida 22),
# Diomedes <- (Diomedes 6), (Diomed 18),
# Hector <- (HECTOR 20),
# Helen <- (HELEN 8), (Helenus 11),
# Menelaus <- (Menelaus 7),
# Pandarus <- (Pandar 25),
# Paris <-
# Patroclus <-
# Thersites <-
# Troilus <- (Troilus 14),
#
# Book: Hard_Times_Charles_Dickens
# Cecelia Jupe <- (Sissy Jupe 53),
# Jane Gradgrind <- (Jane 13), (Mr. Thomas Gradgrind 25),
# Josiah Bounderby <- (MR. BOUNDERBY 9), (Josiah Bounderby 16),
# Jr <-
# Louisa <- (Miss Louisa 31),
# Mrs. Sparsit <- (Mrs. Sparsit 24),
# Rachael <- (Rachael 34),
# Stephen Blackpool <- (STEPHEN BLACKPOOL 27),
# Thomas Gradgrind <- (Mr. Thomas Gradgrind 25),
#
# Book: The_Republic_Plato
# Aporia <-
# Appetite <-
# Auxiliary <-
# Belief <-
# Empirical <-
# Guardian <-
# Instrumental reason <-
# Kallipolis <-
# Knowledge <-
# Philosopher-king <-
# Producers <-
# Reason <-
# Sophist <-
# Spirit <-
#
# Book: Uncle_Tom&rsquo;s_Cabin_Harriet_Beecher_Stowe
# Arthur Shelby <- (Mr. Shelby 90),
# Augustine St. Clare <- (Augustine St. Clare 98),
# Aunt Chloe <- (Aunt Chloe 53),
# Eliza Harris <- (GEORGE HARRIS 65), (Eliza Harris 113),
# Emily Shelby <- (Mr. Shelby 90), (Emily 94),
# Eva <- (Miss Eva 41), (Evangeline 82),
# George Harris <- (GEORGE HARRIS 65),
# George Shelby <- (George Shelby 61), (GEORGE HARRIS 65), (Mr. Shelby 90),
# Mr. Haley <- (Mr. Haley 71),
# The Quakers <- (Quaker 3), (Quakers 60),
# Tom Loker <- (Tom Loker 92),
# Uncle Tom <- (Uncle Tom 47), (Tom Loker 92),
#
# Book: Silas_Marner_George_Eliot
# Aaron Winthrop <- (Aaron 23), (Ben Winthrop 29), (Dolly Winthrop 34),
# Dolly Winthrop <- (Ben Winthrop 29), (Dolly Winthrop 34),
# Dunstan Cass <- (Dunstan Cass 32),
# Eppie <- (Eppie 27),
# Godfrey Cass <- (Mrs. Godfrey Cass 18), (Mr. Godfrey Cass 35),
# Molly Farren <- (Molly 12),
# Nancy Lammeter <- (Miss Nancy Lammeter 4),
# Priscilla Lammeter <- (Miss Nancy Lammeter 4), (Miss Priscilla Lammeter 26),
# Silas Marner <- (Silas Marner 47),
# Squire Cass <- (Squire Cass 28),
# The peddler <-
# William Dane <- (William Dane 51),
#
# Book: King_John_William_Shakespeare
# Arthur <- (ARTHUR 1),
# Austria <-
# Blanche <- (Lady Blanch 17),
# Constance <- (Lady Constance 21),
# Eleanor <-
# Hubert <- (Hubert 2),
# King John <- (KING JOHN 24),
# Louis <- (Louis 13),
# Pandolf <-
# Philip <- (KING PHILIP 23), (-- Philip 25),
# Salisbury <- (Lord Salisbury 10),
# The Bastard <-
#
# Book: The_American_Henry_James
# Christopher Newman <- (Christopher Newman 34), (Mr. Newman 49),
# Claire de Bellegarde (the Comtesse de Cintré) <- (Claire de Cintre 2), (M. de Bellegarde 39),
# Lizzie Tristram <- (Lizzie 9), (Mrs. Tristram 36), (Mr. Tristram 48),
# Noémie Nioche <-
# The Marquis de Bellegarde <- (Marquis de Bellegarde 15), (M. de Bellegarde 39),
# The Marquise de Bellegarde <- (Marquise de Bellegarde 4), (M. de Bellegarde 39),
# The young Marquise de Bellegarde <- (Marquise de Bellegarde 4), (M. de Bellegarde 39),
# Tom Tristram <- (Tom Tristram 16), (Mrs. Tristram 36), (Mr. Tristram 48),
# Urbain de Bellegarde (the young Marquis de Bellegarde) <- (Urbain de Bellegarde 12), (Marquis de Bellegarde 15), (M. de Bellegarde 39),
# Valentin de Bellegarde (the young Comte de Bellegarde) <- (Valentin de Bellegarde 11), (Mr. Valentin 24), (M. de Bellegarde 39),
#
# Book: The_Merry_Wives_of_Windsor_William_Shakespeare
# Anne Page <- (Anne Page 18),
# Caius <- (Caius 1),
# Falstaff <- (John Falstaff 23),
# Fenton <- (Master Fenton 7),
# Ford <- (Mistress Ford 9), (Master Ford 24),
# Mistress Ford <- (Mistress Ford 9), (Master Ford 24),
# Mistress Page <-
# Mistress Quickly <-
# Page <- (Nan Page 11), (Anne Page 18),
# Sir Hugh Evans <- (HUGH EVANS 27),
# Slender <-
#
# Book: Swann's_Way_Marcel_Proust
# Adolphe <- (Adolphe 18),
# Aunt Léonie <-
# Bloch <- (Bloch 20),
# Charles Swann <- (Charles 6), (M. Swann 17),
# Comte de Forcheville <- (M. de Forcheville 48),
# Eulalie <- (Eulalie 108),
# Françoise <-
# Gilberte <- (Gilbert 42), (Gilberte Swann 123),
# M. de Charlus <- (M. de Charlus 38),
# Marcel <- (Marcel Proust 62),
# Marcel's father <-
# Marcel's grandparents <-
# Marcel's mother <-
# Odette <- (Odette de Cr 91),
# Verdurins <- (M. Verdurin 2), (Verdurins 56),
#
# Book: Anna_Karenina_Leo_Tolstoy
# Alexei Alexandrovich Karenin <- (Alexey Alexandrovitch Karenin 10),
# Alexei Kirillovich Vronsky <- (Kirillov 107), (Alexey Vronsky 208),
# Anna Arkadyevna Karenina <- (Alexey Alexandrovitch Karenin 10), (Madame Karenina 66), (Anna Arkadyevna 114),
# Darya Alexandrovna Oblonskaya (Dolly) <- (Oblonskaya 125), (Dolly 139), (Darya Alexandrovna 167),
# Ekaterina Alexandrovna Shcherbatskaya (Kitty) <- (Kitty Shtcherbatskaya 65), (Ekaterina 143),
# Konstantin Dmitrich Levin <- (Konstantin Dmitrievitch Levin 52),
# Nikolai Dmitrich Levin <- (Konstantin Dmitrievitch Levin 52),
# Sergei Alexeich Karenin (Seryozha) <- (Alexey Alexandrovitch Karenin 10), (Seryozha 212),
# Stepan Arkadyich Oblonsky (Stiva) <- (Stiva 30), (Pyotr Oblonsky 100),
#
# Book: The_Comedy_of_Errors_William_Shakespeare
# Abbess <-
# Adriana <- (Adriana 0),
# Angelo <- (Angelo 6),
# Antipholus of Ephesus <-
# Antipholus of Syracuse <-
# Dromio of Ephesus <-
# Dromio of Syracuse <-
# Egeon <-
# Luce <- (Luce 10),
# Luciana <- (Luciana 5),
# Merchant <-
#
# Book: Henry_IV_Part_2_William_Shakespeare
#  <-
#  Humphrey <- (HUMPHREY 12),
# Archbishop of York <- (York 53),
# Bardolph <- (Lord Bardolph 0),
# Duke of Clarence <- (Thomas of Clarence 29),
# Duke of Gloucester <-
# Duke of Lancaster <- (Lord John of Lancaster 44),
# Earl of Surrey <- (Surrey 27),
# Earl of Warwick <- (Warwick 18),
# Earl of Westmoreland <- (Westmoreland 15),
# Gower <- (GOWER 14),
# Hastings <- (LORD HASTINGS 41),
# King Henry IV <- (Henry IV 28),
# Mowbray <- (LORD MOWBRAY 21),
# Page <-
# Peto <- (PETO 2),
# Poins <- (Poins 37),
# Prince Hal (later King Henry V) <- (Hal 7), (Henry IV 28),
# Prince John <- (Lord John of Lancaster 44), (Prince John 48),
# Sir John Blunt <- (Lord John of Lancaster 44), (Prince John 48),
# Sir John Falstaff <- (Lord John of Lancaster 44), (Prince John 48), (JOHN FALSTAFF 51),
# The Lord Chief Justice <-
# Thomas <- (Thomas of Clarence 29),
#
# Book: The_Aeneid_Virgil
# Achates <-
# Aeneas <- (Aeneas 2),
# Amata <- (Amata 58),
# Anchises <- (Anchises 111),
# Ascanius <- (Ascanius 85),
# Creusa <- (Creusa 72),
# Dido <- (Dido 155),
# Evander <-
# Latinus <-
# Lavinia <- (Lavinia 41),
# Pallas <- (Young Pallas 5),
# Turnus <- (Turnus 37),
#
# Book: Henry_VI_Part_3_William_Shakespeare
# Clifford <- (Cliffords 28), (Lord Clifford 33), (Clif 35),
# Edward <- (Edwards 5), (Sonne Edward 27), (Ed 63), (Prince Edward 67), (Edw 74), (Edward King 82),
# George <- (George 30),
# Henry <- (Henry 100),
# Lady Bona <- (Lady Bona 92),
# Lady Gray <- (Lady Gray 40),
# Louis <-
# Margaret <- (Queene Margaret 70), (Marg 103),
# Prince Edward <- (Sonne Edward 27), (Prin 58), (Ed 63), (Prince Edward 67), (Edw 74), (Edward King 82),
# Richard <- (Richard 64), (Rich 95),
# Rutland <-
# Warwick <- (Warwicke 20), (Warw 73), (Lord Warwick 81),
# York <- (Duke of YORKE 56), (House of Yorke 88),
#
# Book: Ulysses_James_Joyce
# Cissy <- (Ciss 118), (CISSY CAFFREY 538),
# Denis Breen <- (Denis Breen 57), (Mrs Breen 106),
# Dilly <- (Dilly Dedalus 376),
# Edy Boardman <- (Edy Boardman 690),
# Garrett Deasy <- (Mr Garrett Deasy 196),
# Gerty MacDowell <- (Gerty Macdowell 378),
# Haines <- (MR HAINES 428), (-- Haines 526),
# Hugh (“Blazes”) Boylan <- (Hugh C. Love 487), (Blazes Boylan 628),
# Josie (née Powell) <- (Josie Powell 626),
# Leopold Bloom <- (Leo 182), (Mr Leopold Bloom 295), (Milly Bloom 387),
# Malachi (Buck) Mulligan <- (Mr Malachi Mulligan 50), (BUCK MULLIGAN 166),
# Marion (Molly) Bloom <- (Mrs Marion Bloom 184), (Moll 219), (Mr Leopold Bloom 295), (Molly 369), (Milly Bloom 387), (Mario 461),
# Martha Clifford <- (Martha Clifford 212),
# Martin Cunningham <- (MARTIN CUNNINGHAM 32),
# Millicent (Milly) Bloom <- (Millicent 92), (Mr Leopold Bloom 295), (Milly Bloom 387),
# Simon Dedalus <- (Simon Dedalus 547), (Stephen Dedalus 599),
# Stephen Dedalus <- (Stephen Dedalus 599),
#
# Book: The_Iliad_Homer
# Achilles <- (Noble Achilles 33),
# Agamemnon (also called “Atrides”) <- (Agamemnon 106),
# Great Ajax <- (Ajax 5),
# Hector <- (Hector son of Priam 78), (O Hector 203),
# Helen <- (Helenus 63), (Argive Helen 198),
# Little Ajax <- (Ajax 5),
# Menelaus <- (O Menelaus 68),
# Nestor <- (Nestor of Gerene 120),
# Odysseus <-
# Paris (also known as “Alexander”) <-
# Patroclus <-
# Peleus <- (Peleus 166),
# Priam <- (Hector son of Priam 78),
# The Myrmidons <- (Myrmidons 201),
#
# Book: Paradise_Lost_John_Milton
# Abdiel <- (Abdiel 16),
# Adam <- (Adam 24),
# Beelzebub <-
# Belial <-
# Death <-
# Eve <- (Eve 14),
# Gabriel <- (Gabriel 25),
# God the Father <- (Son of God 6),
# God the Son <- (Son of God 6),
# Mammon <-
# Michael <- (Michael 34),
# Satan <-
# Sin <-
#
# Book: The_Merchant_of_Venice_William_Shakespeare
# Antonio <- (Signior Antonio 11), (O my Antonio 18),
# Bassanio <- (Lord Bassanio 27),
# Gratiano <- (GRATIANO 5),
# Jessica <- (Jessica 29),
# Launcelot Gobbo <- (LAUNCELOT GOBBO 1),
# Lorenzo <- (Lorenzo 25),
# Nerissa <- (Nerissa 24),
# Portia <- (Portia 22),
# Salarino <-
# Shylock <-
# Solanio <-
# The prince of Arragon <-
# The prince of Morocco <-
# Tubal <-
#
# Book: Adam_Bede_George_Eliot
# Adam Bede <- (Adam Bede 116),
# Aldophous Irwine <- (Mr. Irwine 17),
# Bartle Massey <- (Bartle Massey 18),
# Captain Arthur Donnithorne <- (Mr. Arthur Donnithorne 12), (Squire Donnithorne 123),
# Dinah Morris <- (Dinah Morris 135),
# Gyp <- (Gyp 95),
# Hetty Sorrel <- (Hetty Sorrel 55),
# Lisbeth Bede <- (Lisbeth Bede 20), (Adam Bede 116),
# Martin Poyser <- (Martin Poyser 33), (Mrs. Poyser 117),
# Rachel Poyser <- (Martin Poyser 33), (Rachel 56), (Mrs. Poyser 117),
# Sarah Stone <-
# Seth Bede <- (Seth Bede 105), (Adam Bede 116),
# Thias Bede <- (Thias Bede 101), (Adam Bede 116),
# Wiry Ben <- (Wiry Ben 112),
#
# Book: Romeo_and_Juliet_William_Shakespeare
# Balthasar <- (Balthasar 12),
# Benvolio <- (Ben 4), (Benvolio 31),
# Capulet <- (Capulets 3), (V. Capulet 5), (Cap 9), (Lady Capulet 25),
# Friar Lawrence <-
# Juliet <- (JULIET 23),
# Mercutio <-
# Montague <- (Montague 19), (Montagues 27),
# Paris <-
# Romeo <- (Romeo 0),
# Rosaline <- (Rosaline 13),
# The Nurse <-
# Tybalt <-
#
# Book: O_Pioneers!_Willa_Cather
# Alexandra Bergson <- (Alexandra Bergson 30),
# Amedee Chevalier <- (Amedee Chevalier 3),
# Carl Linstrum <- (CARL LINSTRUM 13),
# Emil Bergson <- (Emil Bergson 1), (Alexandra Bergson 30),
# Frank Shabata <- (Frank Shabata 16),
# John Bergson <- (John Bergson 25), (Alexandra Bergson 30),
# Lou Bergson <- (Lou 29), (Alexandra Bergson 30),
# Marie Shabata <- (Frank Shabata 16), (Marie Shabata 36), (Marie Tovesky 37),
# Oscar Bergson <- (Oscar 9), (Alexandra Bergson 30),
#
# Book: Narrative_of_the_Life_of_Frederick_Douglass_Frederick_Douglass
# Anna Murray <- (Anna Murray 65),
# Aunt Hester <- (Hester 58),
# Captain Anthony <- (Anthony 63),
# Captain Thomas Auld <- (Thomas Auld 22),
# Colonel Edward Lloyd <- (Mr. Edward Covey 12), (Lloyd 16),
# Edward Covey <- (Mr. Edward Covey 12),
# Frederick Douglass <- (FREDERICK DOUGLASS 34),
# Harriet Bailey <- (Frederick Augustus Washington Bailey 27), (Henry Bailey 32),
# Hugh Auld <- (Thomas Auld 22), (Master Hugh 50),
# Lucretia Auld <- (Mrs. Lucretia 18), (Thomas Auld 22),
# Sophia Auld <- (Thomas Auld 22),
# Wendell Phillips <-
# William Lloyd Garrison <- (Lloyd 16), (Mr. William Hamilton 59),
#
# Book: Bleak_House_Charles_Dickens
# Ada Clare <- (Miss Ada Clare 34),
# Esther Summerson <- (Miss Esther Summerson 14),
# Inspector Bucket <-
# Lady Dedlock <- (Leicester Dedlock 33), (Lady Dedlock 58),
# Mademoiselle Hortense <- (Mademoiselle Hortense 53), (Ma 141),
# Mr. Badger <- (Mrs. Bayham Badger 10), (Mr. Bayham Badger 22),
# Mr. John Jarndyce <- (Mr. Jarndyce 44), (Jo 120), (John Jarndyce 165),
# Mr. Matthew Bagnet <- (Mr. Matthew Bagnet 81), (Mrs. Bagnet 85), (Ma 141),
# Mr. Tulkinghorn <- (Mr. Tulkinghorn 20),
# Mrs. Bagnet <- (Mr. Matthew Bagnet 81), (Mrs. Bagnet 85),
# Mrs. Baytham Badger <- (Mrs. Bayham Badger 10),
# Richard Carstone <- (Mr. Richard Carstone 159),
# Sir Leicester Dedlock <- (Leicester Dedlock 33), (Sir Leicester 39), (Lady Dedlock 58),
#
# Book: Henry_VI_Part_2_William_Shakespeare
# Beaufort <-
# Bolingbroke <-
# Buckingham <-
# Duchess <- (Duch 72),
# Gloucester <-
# Henry <- (Henry King 10), (Henry the Sixt 23),
# Horner <-
# Hume <- (Hume 35),
# Jack Cade <- (Iacke Cade 13),
# Margaret <- (Queene Margaret 80),
# Peter <- (Peter 37),
# Somerset <-
# Suffolk <- (Suff 69), (Lord Suffolke 94), (Duke of Suffolke 101),
# York <- (Manet Yorke 17), (Duke of Yorke 68), (York 112),
#
# Book: Madame_Bovary_Gustave_Flaubert
# Abbé Bournisien <- (Monsieur Bournisien 48),
# Berthe <- (Berthe 32),
# Charles Bovary <- (Madame Bovary 1), (Charles 2),
# Emma Bovary <- (Madame Bovary 1), (Mademoiselle Emma 70),
# Guillaumin <- (Monsieur Guillaumin 3),
# Hippolyte <- (Hippolyte 63),
# Justin <- (Justin 39),
# Leon <- (Monsieur Leon Dupuis 0),
# Monsieur Homais <- (Monsieur Rodolphe Boulanger 13), (Monsieur Rouault 46), (Monsieur Homais 60),
# Monsieur Lheureux <- (Monsieur Rodolphe Boulanger 13), (Monsieur Rouault 46), (Monsieur Lheureux 62),
# Rodolphe Boulanger <- (Monsieur Rodolphe Boulanger 13),
# Rouault <- (Monsieur Rouault 46), (Mademoiselle Rouault 74),
# The elder Madame Bovary <- (Madame Bovary 1),
#
# Book: War_and_Peace_Leo_Tolstoy
# Andrew Bolkonski <- (Andrew Bolkonski 251), (Prince Bolkonski 274),
# Boris Drubetskoy <- (Boris Drubetskoy 419),
# Count Ilya Rostov <- (Ilya Rostov 117), (Count Bennigsen 423),
# Countess Natalya Rostova <- (Ilya Rostov 117), (Nataly 195), (Natasha Rostova 260), (Count Bennigsen 423),
# Helene Kuragina <- (Countess Helene 9), (Vasili Kuragin 165), (Kuragina 318),
# Julie Karagina <- (Julie Karagina 68), (Julie Drubetskaya 336),
# Lise Bolkonskaya <- (Lise 89), (Mary Bolkonskaya 242),
# Mademoiselle Bourienne <- (Mademoiselle Bourienne 133),
# Mary Bolkonskaya <- (Mary Bolkonskaya 242),
# Natasha Rostova <- (Ilya Rostov 117), (Natasha Rostova 260),
# Nicholas Rostov <- (Ilya Rostov 117), (Nicholas Rostov 247), (Prince Nicholas 435),
# Petya Rostov <- (Ilya Rostov 117), (Petya 256),
# Pierre Bezukhov <- (Pierre Bezukhov 121),
# Prince Bolkonski <- (Prince Andrew 61), (Prince Anatole 87), (Andrew Bolkonski 251), (Prince Bolkonski 274), (Prince Nicholas 435), (Prince Vasili 436),
#
# Book: Middlemarch_George_Eliot
# Arthur Brooke <- (DOROTHEA BROOKE 16), (Arthur 204), (MISS BROOKE 219),
# Celia Brooke <- (DOROTHEA BROOKE 16), (Celia 139), (MISS BROOKE 219),
# Dorothea Brooke <- (DOROTHEA BROOKE 16), (MISS BROOKE 219),
# Edward Casaubon <- (MR. CASAUBON 29), (EDWARD CASAUBON 74),
# Fred Vincy <- (Mr. Fred 94), (Fred Vincy 117), (Rosamond Vincy 228),
# Harriet Bulstrode <- (Harriet Vincy 22), (Mr. Bulstrode 223),
# Lucy Vincy <- (Lucy 178), (Rosamond Vincy 228),
# Mr. Wrench <- (Mr. Wrench 170),
# Nicholas Bulstrode <- (Nicholas Bulstrode 209), (Mr. Bulstrode 223),
# Rosamond Vincy <- (Rosamond Vincy 228),
# Sir Godwin Lydgate <- (Mr. Lydgate 17), (GODWIN LYDGATE 31),
# Sir James Chettam <- (James Chettam 46),
# Tertius Lydgate <- (Mr. Lydgate 17), (Tertius 42),
# Walter Vincy <- (Walter Scott 88), (Rosamond Vincy 228),
# Will Ladislaw <- (Mr. Ladislaw 27), (Will Ladislaw 127),
#
# Book: Pride_and_Prejudice_Jane_Austen
# Charles Bingley <- (Charles 4), (Mr. Bingley 67),
# Charlotte Lucas <- (Lady Lucas 18), (Charlotte Lucas 43),
# Elizabeth Bennet <- (Miss Eliza Bennet 11), (Miss Elizabeth Bennet 48),
# Fitzwilliam Darcy <- (Mr. Darcy 1), (Fitzwilliam 66),
# George Wickham <- (George Wickham 9), (Mr. Wickham 69),
# Georgiana Darcy <- (Mr. Darcy 1), (Georgiana 6),
# Jane Bennet <- (Jane Austen 3), (Miss Elizabeth Bennet 48),
# Lady Catherine de Bourgh <- (Lady Catherine de Bourgh 2),
# Lydia Bennet <- (Miss Lydia Bennet 47), (Miss Elizabeth Bennet 48),
# Miss Bingley <- (Miss Bingley 49), (Mr. Bingley 67),
# Mr. Bennet <- (Miss Elizabeth Bennet 48), (Mr. Bennet 59),
# Mr. Collins <- (Mr. Collins 14),
# Mr. Gardiner <- (Mrs. Gardiner 38), (Mr. Gardiner 68),
# Mrs. Bennet <- (Miss Elizabeth Bennet 48), (Mrs. Bennet 50),
# Mrs. Gardiner <- (Mrs. Gardiner 38), (Mr. Gardiner 68),
#
# Book: Candide_Voltaire
# Cacambo <- (Cacambo 8),
# Candide <- (Candide 35),
# Cunégonde <-
# Don Fernando d’Ibaraa y Figueora y Mascarenes y Lampourdos y Souza <- (Souza 5),
# Don Issachar <- (Don Issachar 26),
# Jacques (the Anabaptist) <-
# Martin <- (Mr. Martin 36),
# Pangloss <- (Dr. Pangloss 3),
# Paquette <- (PAQUETTE 2),
# The Commander or the baron <-
# The Grand Inquisitor <-
# The old woman <-
# Vanderdendur <- (Mynheer Vanderdendur 22),
#
# Book: The_Jungle_Upton_Sinclair
# Antanas Rudkus <- (Antanas Rudkus 14), (Dede Antanas 50), (Jurgis Rudkus 55),
# Dede Antanas Rudku <- (Dede Antanas 50),
# Grandmother Majauszkiene <- (Majauszkiene 43),
# Jack Duane <- (Jack Duane 51),
# Juozapas Lukoszaite <- (Juozapas 44),
# Jurgis Rudkus <- (Jurgis Rudkus 55),
# Marija Berczynskas <- (Marija Berczynskas 17),
# Mike Scully <- (Mike Scully 1),
# Miss Henderson <- (Miss Henderson 42),
# Ona Lukoszaite <- (Little Ona 59),
# Phil Connor <- (Phil Connor 41),
# Stanislovas Lukoszaite <- (Stanislovas 35),
# Teta Elzbieta Lukoszaite <- (Teta Elzbieta 62),
#
# Book: Henry_VI_Part_1_William_Shakespeare
# Basset <-
# Charles <- (Charles the Dauphin 29),
# Gloucester <-
# Joan <- (JOAN LA PUCELLE 5),
# John <- (JOHN TALBOT 23), (JOHN FASTOLFE 30),
# King Henry VI <- (Henry the Fifth 7), (King 22),
# Margaret <- (Lady Margaret 10),
# Mortimer <- (EDMUND MORTIMER 31),
# Richard Plantagenet <- (RICHARD PLANTAGENET 18),
# Somerset <-
# Suffolk <-
# Talbot <- (Talbots 11), (LORD TALBOT 12), (JOHN TALBOT 23),
# Vernon <-
# Winchester <- (Winchester 27),
#
# Book: Anne_of_Green_Gables_L._M._Montgomery
# Anne Shirley <- (Anne Shirley 54),
# Aunt Josephine <- (Miss Josephine Barry 2),
# Diana Barry <- (Miss Josephine Barry 2), (Diana Barry 85),
# Gilbert Blythe <- (Gilbert Blythe 39), (Gil 75),
# Josie Pye <- (Josie Pye 91),
# Marilla Cuthbert <- (Matthew Cuthbert 80), (Miss Marilla Cuthbert 96),
# Matthew Cuthbert <- (Matthew Cuthbert 80), (Miss Marilla Cuthbert 96),
# Miss Muriel Stacy <- (Miss Stacy 33),
# Mr. Phillips <- (Mr. Phillips 35),
# Mrs. Allan <- (Mrs. Allan 47),
# Mrs. Barry <- (Miss Josephine Barry 2), (Mrs. Barry 50), (Diana Barry 85),
# Mrs. Rachel Lynde <- (Mrs. Rachel Lynde 66),
#
# Book: A_Midsummer_Night&rsquo;s_Dream_William_Shakespeare
# Demetrius <- (Demetrius 16),
# Egeus <- (EGEUS 18),
# Helena <- (Helena 9), (Helen 10),
# Hermia <-
# Hippolyta <-
# Lysander <- (Lysander 5),
# Nick Bottom <- (Nick Bottom 4),
# Oberon <- (Oberon 0),
# Philostrate <-
# Puck <-
# Theseus <-
# Titania <-
#
# Book: Babbitt_Sinclair_Lewis
# Eunice Littlefield <- (Eunice Littlefield 23),
# George F. Babbitt <- (Mr. George F. Babbitt 69),
# Henry T. Thompson <- (Mrs. Henry T. Thompson 109),
# Jake Offutt <- (Jake Offutt 91),
# Myra Babbitt <- (Mr. George F. Babbitt 69), (Myra Babbitt 178),
# Paul Riesling <- (Paul Riesling 16),
# Seneca Doane <- (Seneca Doane 54),
# Sir Gerald Doak <- (Gerald Doak 93),
# T. Cholmondeley Frink <- (T. Cholmondeley Frink 1),
# Tanis Judique <- (Tanis Judique 71),
# Ted Babbitt <- (Ted 2), (Mr. George F. Babbitt 69),
# Tinka Babbitt <- (Mr. George F. Babbitt 69), (Tinka 125),
# Verona Babbitt <- (Mr. George F. Babbitt 69), (Verona 100),
# Zilla Riesling <- (Zilla Riesling 150),
#
# Book: William_Shakespeare_Henry_IV_Part_1
# Archibald <- (Archibald 42),
# Earl of Northumberland <-
# Earl of Westmoreland <- (Westmoreland 13),
# Hotspur <-
# King Henry IV <- (King 14), (Henry IV 22),
# Lord John of Lancaster <- (Lord John of Lancaster 45), (John Falstaff 48),
# Ned Poins <- (Ned 3),
# Owain Glyndˆwr <-
# Prince Harry <- (Harry Percy 4), (Prince of Wales 55),
# Sir John Falstaff <- (Jack Falstaff 9), (John Falstaff 48),
# Sir Walter Blunt <- (Walter Blunt 38),
# The Archbishop of York <- (Archbishop of York 49),
#
# Book: Cyrano_de_Bergerac_Edmond_Rostand
# Baron Christian de Neuvillette <- (Baro 11), (Christian 51),
# Carbon de Castel-Jaloux <- (Carbon de Castel-Jaloux 35),
# Comte de Guiche <- (Monsieur de Guiche 21),
# Cyrano de Bergerac <- (Monsieur de Bergerac 54), (Cyrano 61),
# Le Bret <- (LE BOURGEOIS 18), (Voilà Le Bret 41), (Le Bret et Ragueneau 52), (Monsieur Le Bret 56),
# Ligniere <-
# Ragueneau <- (Le Bret et Ragueneau 52),
# Roxane <- (Roxane 34),
# The duenna <-
# Vicomte de Valvert <-
#
# Book: Spanish_Tragedy_Thomas_Kyd
# Balthazar <- (Don Balthazar 24), (Prince Balthazar 27),
# Bazulto <- (Don Bazulto 2),
# Bel-Imperia <-
# Ghost of Andrea <- (Don Andrea 31),
# Hieronimo <- (HIERONIMO 8),
# Horatio <- (Signior Horatio 14), (DON HORATIO 23),
# Isabella <- (Isabella 5), (ISABELL 10),
# Lorenzo <- (Don Lorenzo 25),
# Pedringano <- (Pedringano 12),
# Revenge <-
# Serberine <- (Serberine 11),
# The King <-
# The Viceroy <- (Viceroy 9),
#
# Book: The_Winter's_Tale_William_Shakespeare
# Antigonus <- (Antigonus 7),
# Camillo <- (Camillo 8),
# Florizel <- (Florizel 14),
# Hermione <- (Hermione 15),
# Leontes <- (Leontes 0),
# Mamillius <-
# Paulina <- (Paulina 11),
# Perdita <- (Perdita 3),
# Polixenes <-
# Shepherd <-
#
# Book: Great_Expectations_Charles_Dickens
# Abel Magwitch (“The Convict”) <- (Abel Magwitch 83),
# Bentley Drummle <- (Mrs. Bentley Drummle 78), (Mr. Drummle 84),
# Biddy <- (Biddy 71),
# Estella <- (Miss Estella 31),
# Herbert Pocket <- (Herbert Pocket 1),
# Jaggers <- (MR. JAGGERS 51), (Mr Jaggers 63),
# Joe Gargery <- (Mrs. Joe Gargery 92),
# Miss Havisham <- (Miss Havisham 64),
# Molly <- (Molly 20),
# Mrs. Joe <- (Mrs. Joe Gargery 92),
# Pip <- (Mr. Pip 4),
# Startop <- (Startop 21),
# Uncle Pumblechook <- (Mr. Pumblechook 19), (Uncle Pumblechook 40),
# Wemmick <- (Mrs. Wemmick 29), (Mr. Wemmick 87),
#
# Book: Henry_V_William_Shakespeare
# Ancient Pistol <-
# Bardolph <- (Bardolph 43),
# Cambridge <-
# Captain Fluellen <- (Fluellen 26),
# Captain Gower <- (Gower 16),
# Catherine <-
# Isabel <-
# King Henry V <- (Henry Lord Scroop 15), (King 18),
# Nim <-
# Salisbury <- (SALISBURY 2),
# Scrope <-
# Sir John Falstaff <- (John Bates 3),
# Sir Thomas Erpingham <- (THOMAS GREY 7), (THOMAS ERPINGHAM 22),
# The Dauphin <- (Prince Dauphin 53),
# The Dukes of Exeter <- (John Duke 4),
# The King of France Charles VI. <- (King 18), (Charles Delabreth 28), (Charles the Great 45),
# Westmorland <-
# and Grey Three conspirators against King Henry. <- (THOMAS GREY 7), (Henry Lord Scroop 15), (King 18),
# and Warwick <- (WARWICK 20),
# Book: Dubliners_James_Joyce
# Corley <- (Corley 89),
# Farrington <- (Farrington 44),
# Father Flynn <- (Nosey Flynn 29),
# Gallaher <- (Ignatius Gallaher 122),
# Joe Donnelly <- (Joe Dillon 88),
# Lenehan <- (Lenehan 16),
# Little Chandler <- (Little Chandler 102),
# Mahony <- (Mahony 25),
# Mangan’s sister <- (Mangan 98),
# Maria <- (Maria 126),
# Mr. Alleyne <- (Mr. Alleyne 104),
# Mr. Doran <- (Mr. Doran 129),
# Mr. Duffy <- (Mr. Duffy 118),
# Mr. Holohan <- (Mr. Holohan 7),
# Mrs. Kearney <- (Mrs. Kearney 15),
# Mrs. Mooney <- (MRS. MOONEY 74),
# Mrs. Sinico <- (Mrs. Sinico 11),
# Old Cotter <- (Mr. Cotter 52),
# “An Encounter” narrator <-
# “Araby” narrator <-
# “The Sisters” narrator <-
#
# Book: As_You_Like_It_William_Shakespeare
# Adam <- (Adam 14),
# Celia <- (Celia 0),
# Corin <- (Corin 5),
# Duke Frederick <- (Duke 1), (Frederick 25),
# Duke Senior <- (Duke 1),
# Jaques <- (Monsieur Jaques 24),
# Lord Amiens <-
# Oliver <- (OLIVER MARTEXT 26),
# Orlando <- (Orlando 11),
# Phoebe <-
# Rosalind <- (Rosalinde 9), (Rosalind 13),
# Silvius <- (Silvius 16),
# Touchstone <-
#
# Book: Dr._Jekyll_and_Mr._Hyde_Robert_Louis_Stevenson
# Dr. Hastie Lanyon <- (DR. LANYON 2),
# Dr. Henry Jekyll <- (Dr. Henry Jekyll 0),
# Mr. Edward Hyde <- (Mr. Hyde 9), (Edward Hyde 13),
# Mr. Enfield <- (Mr. Enfield 5),
# Mr. Gabriel John Utterson <- (Mr. Utterson 8),
# Mr. Guest <- (Mr. Guest 4),
# Mr. Poole <- (Poole 11),
# Sir Danvers Carew <- (CAREW 6), (Danvers 12),
#
# Book: Dracula_Bram_Stoker
# Arthur Holmwood <- (Ho 2), (Arthur Holmwood 8), (Art 25),
# Count Dracula <- (Count Dracula 42),
# John Seward <- (Dr. John Seward 71),
# Jonathan Harker <- (JONATHAN HARKER 21),
# Lucy Westenra <- (Miss Lucy Westenra 75),
# Mina Murray <- (Miss Mina Murray 50),
# Mrs. Westenra <- (Mrs. Westenra 68), (Miss Lucy Westenra 75),
# Quincey Morris <- (Mr. Quincey Morris 72),
# Renfield <- (Mr. Renfield 46),
# Van Helsing <- (Dr. Van Helsing 28), (ABRAHAM VAN HELSING 66),
#
# Book: The_House_of_Mirth_Edith_Wharton
# Bertha Dorset <- (Mrs. George Dorset 24), (Bertha Dorset 70),
# Carry Fisher <- (Carry Fisher 34), (Mrs. Fisher 73),
# George Dorset <- (Mrs. George Dorset 24), (George Dorsets 49), (Bertha Dorset 70),
# Gerty Farish <- (Gerty Farish 5),
# Gus Trenor <- (Mrs. Trenor 3), (Gus Trenor 15),
# Gwen Stepney <- (Gwen Van Osburgh 1), (Mrs. Jack Stepney 11), (Gwen Stepney 72),
# Jack Stepney <- (Mrs. Jack Stepney 11),
# Judy Trenor <- (Mrs. Trenor 3), (Judy Trenor 27),
# Lawrence Selden <- (Mr. Lawrence Selden 83),
# Lily Bart <- (Miss Lily Bart 64),
# Mrs. Peniston <- (Mrs. Peniston 44),
# Ned Silverton <- (Ned Silverton 2),
# Simon Rosedale <- (Mr. Simon Rosedale 52),
#
# Book: Herland_Charlotte_Perkins_Gilman
# Alima <- (Alima 11),
# Celis <- (Celis 9),
# Ellador <- (Ellador 4),
# Jeff Margrave <- (Jeff Margrave 0),
# Moadine <- (Moadine 5),
# Somel <- (Somel 8),
# Terry Nicholson <- (Terry 10),
# Vandyck Jennings <- (Van 2),
#
# Book: Howards_End_E._M._Forster
# Aunt Juley Mund <- (Aunt Juley 62),
# Charles Wilcox <- (Charles Wilcox 15), (Mr. Wilcox 33), (Mrs. Warrington Wilcox 80),
# Dolly Wilcox <- (Charles Wilcox 15), (Dolly 28), (Mr. Wilcox 33), (Mrs. Warrington Wilcox 80),
# Evie Wilcox <- (Charles Wilcox 15), (Mr. Wilcox 33), (Evie Wilcox 70), (Mrs. Warrington Wilcox 80),
# Helen Schlegel <- (HELEN 10), (MISS SCHLEGEL 47),
# Henry Wilcox <- (Charles Wilcox 15), (Mr. Wilcox 33), (Mrs. Warrington Wilcox 80), (Henry 100),
# Jacky Bast <- (Jacky 48), (Leonard Bast 51),
# Leonard Bast <- (Leonard Bast 51),
# Margaret Schlegel <- (MISS SCHLEGEL 47), (Margaret 59),
# Paul Wilcox <- (Charles Wilcox 15), (Mr. Wilcox 33), (St. Paul 42), (Paul Wilcox 75), (Mrs. Warrington Wilcox 80),
# Ruth Wilcox <- (Ruth Wilcox 6), (Charles Wilcox 15), (Mr. Wilcox 33), (Mrs. Warrington Wilcox 80),
# Tibby <- (Tibby 26),
#
# Book: A_Doll&rsquo;s_House_Henrik_Ibsen
# Anne-Marie <- (Anne 3),
# Bob <- (Bob 13),
# Dr. Rank <-
# Emmy <-
# Krogstad <- (Nils Krogstad 0), (Mr. Krogstad 9),
# Mrs. Linde <- (MRS. LINDE 8),
# Nora <- (-- Nora 4),
# Torvald Helmer <- (Torvald Helmer 6),
# and Ivar <- (Ivar 7),
#
# Book: Hamlet_William_Shakespeare
# Claudius <-
# Cornelius <- (Cornelius 8),
# Gertrude <- (Gertrude 22),
# Guildenstern <- (Guildenstern 6), (Guil 18),
# Hamlet <- (Lord Hamlet 15),
# Horatio <- (Horatio 2), (Hor 5),
# Laertes <- (Laer 9), (Laertes 24),
# Ophelia <- (Ophelia 35),
# Polonius <-
# Rosencrantz <- (Ros 11), (Rosencrantz 32),
# The Ghost <-
# Voltimand <- (Voltimand 20), (Volt 33),
#
# Book: Hedda_Gabler_Henrik_Ibsen
# Aunt Rina <- (Miss Rina 20),
# Berte <-
# Ejlert Lövborg <-
# Hedda Gabler <- (Hedda Gabler 11),
# Judge Brack <- (Mr. Brack 27),
# Juliane Tesman <- (Julia 7), (MISS JULIANA TESMAN 8), (Dr. Tesman 16),
# Jürgen Tesman <- (MISS JULIANA TESMAN 8), (Dr. Tesman 16),
# Mrs. Elvsted <- (Mrs. Elvsted 4),
#
# Book: Heart_of_Darkness_Joseph_Conrad
# Brickmaker <-
# Cannibals <-
# Fresleven <- (Fresleven 1),
# General manager <-
# Helmsman <-
# Kurtz <- (Mr. Kurtz 4),
# Kurtz’s African mistress <- (Mr. Kurtz 4),
# Kurtz’s Intended <- (Mr. Kurtz 4),
# Marlow <- (Marlow 5),
# Pilgrims <-
# Russian trader <-
# The men aboard the Nellie <-
#
# Book: Ghosts_Henrik_Ibsen
# Captain Alving <- (MRS. ALVING 2), (MRS ALVING 7),
# Jakob Engstrand <- (Jacob Engstrand 3),
# Johanna <-
# Mrs. Helene Alving <- (MRS. ALVING 2), (Helen 5), (MRS ALVING 7),
# Oswald Alving <- (MRS. ALVING 2), (MRS ALVING 7), (OSWALD ALVING 9),
# Pastor Manders <- (Mr. Manders 8),
# Regina Engstrand <- (REGINA 0), (Jacob Engstrand 3),
#
# Book: Far_from_the_Madding_Crowd_Thomas_Hardy
# Bathsheba Everdene <- (Bathsheba Everdene 53),
# Cainy Ball <- (Cainy Ball 0), (Cain Ball 4),
# Fanny Robin <- (Fanny Robin 6),
# Gabriel Oak <- (GABRIEL OAK 35),
# Jan Coggan <- (Mr. Jan Coggan 41),
# Joseph Poorgrass <- (Joseph Poor 23), (Joseph Poorgrass 60),
# Liddy Smallbury <- (Liddy Smallbury 11),
# Pennyways <- (Baily Pennyways 30),
# Sergeant Francis (Frank) Troy <- (Frank 12), (FRANCIS TROY 50),
# William Boldwood <- (William Smallbury 2), (Mr. Boldwood 36),
#
# Book: Ethan_Frome_Edith_Wharton
# Andrew Hale <- (Andrew Hale 5), (Mrs. Ned Hale 6),
# Denis Eady <- (Denis Eady 22),
# Ethan Frome <- (ETHAN FROME 10),
# Harmon Gow <- (Harmon Gow 8),
# Jotham Powell <- (Jotham Powell 21),
# Mattie Silver <- (Mattie Silver 4), (Matt 14),
# Mrs. Andrew Hale <- (Andrew Hale 5), (Mrs. Ned Hale 6),
# Mrs. Ned Hale <- (Mrs. Ned Hale 6),
# Ned Hale <- (Mrs. Ned Hale 6),
# The Narrator <-
# Zenobia Frome <- (ETHAN FROME 10), (Zenobia 11),
#
# Book: The_Last_of_the_Mohicans_James_Fenimore_Cooper
# Alice Munro <- (Alice 0), (Cora Munro 27),
# Chingachgook <- (Chingachgook 7),
# Colonel Munro <- (Cora Munro 27),
# Cora Munro <- (Cora Munro 27),
# David Gamut <- (David Gamut 36),
# Hawkeye <-
# Magua <- (Magua 10),
# Major Duncan Heyward <- (Duncan Heyward 20),
# Uncas <- (Uncas 11),
#
# Book: King_Lear_William_Shakespeare
# Albany <-
# Cordelia <- (Cordelia 14),
# Cornwall <-
# Edgar <- (EDGAR 3),
# Edmund <- (Edmund Earl 0),
# Fool <-
# Gloucester <-
# Goneril <-
# Kent <- (Kent 6),
# King Lear <- (Lear 12),
# Oswald <- (Oswald 5),
# Regan <- (O Regan 9), (Reg 10),
#
# Book: Sister_Carrie_Theodore_Dreiser
# Carrie Meeber <- (Carrie Meeber 22), (Miss Carrie Madenda 80),
# Charlie Drouet <- (Mrs. Drouet 35), (Charlie 43),
# Fitzgerald <- (Fitzgerald 11),
# George Hurstwood <- (Mr. Hurstwood 70), (George , Jr. 83),
# Hanson <- (Hansons 32), (Hanson 73),
# Jessica Hurstwood <- (Mr. Hurstwood 70), (Jessica 81),
# Jr. <- (George , Jr. 83),
# Julia Hurstwood <- (Mrs. Julia Hurstwood 41), (Mr. Hurstwood 70),
# Minnie <- (Minnie 45),
# Moy <- (Moy 12),
# Mrs. Hale <- (Mrs. Hale 52),
# Mrs. Vance <- (Mr. Vance 1), (Mrs. Vance 57),
#
# Book: Northanger_Abbey_Jane_Austen
# Catherine Morland <- (Catherine Morland 41),
# Eleanor Tilney <- (Eleanor Tilney 19), (Mr. Henry Tilney 31), (Miss Tilney 34),
# Frederick Tilney <- (Mr. Henry Tilney 31), (Miss Tilney 34), (Frederick 46),
# General Tilney <- (Mr. Henry Tilney 31), (Miss Tilney 34),
# Henry Tilney <- (Mr. Henry Tilney 31), (Miss Tilney 34),
# Isabella Thorpe <- (Mrs. Thorpe 28), (Isabella Thorpe 45), (John Thorpe 49),
# James Morland <- (James Morland 20), (Catherine Morland 41),
# John Thorpe <- (Mrs. Thorpe 28), (Isabella Thorpe 45), (John Thorpe 49),
# Mr. Allen <- (Mrs. Allen 4), (Mr. Allen 26),
# Mrs. Allen <- (Mrs. Allen 4),
# Mrs. Thorpe <- (Mrs. Thorpe 28), (Isabella Thorpe 45), (John Thorpe 49),
#
# Book: Julius_Caesar_William_Shakespeare
# Antony <-
# Brutus <- (Decius Brutus 9), (MARCUS BRUTUS 30),
# Calpurnia <- (Calp 48),
# Casca <- (Casc 0),
# Cassius <- (Caie Cassi 3), (Cass 13), (CASSIUS 51),
# Decius <- (Deci 7), (Decius Brutus 9),
# Flavius <-
# Julius Caesar <- (JULIUS CÆSAR 53),
# Lepidus <-
# Murellus <-
# Octavius <- (Octavi 24), (OCTAVIUS 77),
# Portia <- (PORTIA 26),
#
# Book: This_Side_of_Paradise_F._Scott_Fitzgerald
# Alec Connage <- (ALEC CONNAGE 13),
# Amory Blaine <- (Mr. Amory Blaine 84),
# Beatrice Blaine <- (Beatrice O'Hara 33), (Mr. Amory Blaine 84), (Beatrice Blaine 87),
# Burne Holiday <- (Burne Holiday 31),
# Dawson Ryder <- (Dawson Ryder 58),
# Dick Humbird <- (Dick Humbird 110),
# Isabelle Borges <- (Isabelle Borge 22),
# Jesse Ferrenby <- (Jesse Ferrenby 92),
# Monsignor Darcy <- (Monsignor Darcy 109),
# Mr. Ferrenby <- (Mr. Ferrenby 29), (Jesse Ferrenby 92),
# Rosalind Connage <- (ALEC CONNAGE 13), (Rosalind 32),
# Thomas Park D'Invilliers <- (Tom d'Invilliers 43),
#
# Book: The_Taming_of_the_Shrew_William_Shakespeare
# Baptista <- (Signior Baptista 8), (BAPTISTA MINOLA 20),
# Bianca <- (Bianca 16),
# Biondello <- (BIONDELLO 27),
# Gremio <- (Signior Gremio 21),
# Grumio <- (GRUMIO 24),
# Hortensio <- (Signior Hortensio 12),
# Katherine <- (Katherine 28),
# Lucentio <- (Signior Lucentio 23),
# Petruchio <- (Signior Petruchio 35),
# Tranio <- (TRANIO 31),
#
# Book: The_Jew_of_Malta_Christopher_Marlowe
# Abigail <- (Abigail 3),
# Barabas <- (Will Barabas 9),
# Bellamira <- (Bellamira 40),
# Don Lodowick <- (Don Lodowick 14),
# Don Mathias <- (Don Mathias 12),
# Ferneze <- (Ferneze 17),
# Friar Bernardine <-
# Friar Jacomo <- (Jacomo 8),
# Ithamore <- (-- Ithamore 32),
# Katherine <-
# Pilia-Borza <- (Pilia-Borza 25),
#
# Book: Lysistrata_Aristophanes
# Chorus of Old Men <-
# Chorus of Old Women <-
# Commissioner of Public Safety <-
# Four Policemen <-
# Ismenia <-
# Kinesias <-
# Kleonike <-
# Korinthian Girl <-
# Koryphaios of Men <-
# Koryphaios of Women <-
# Lampito <- (Lampito 8),
# Lysistrata <- (Lysistrata 17),
# Myrrhine <- (Myrrhine 6),
#
# Book: Mansfield_Park_Jane_Austen
# Edmund Bertram <- (Mr. Edmund Bertram 58), (Thomas Bertram 59),
# Fanny Price <- (Fanny Price 20),
# Henry Crawford <- (Miss Crawford 4), (Henry Crawford 21), (Mrs. Crawford 75),
# Julia Bertram <- (Julia Bertram 39), (Miss Julia 52), (Mr. Edmund Bertram 58), (Thomas Bertram 59),
# Lady Bertram <- (Lady Bertram 14), (Mr. Edmund Bertram 58), (Thomas Bertram 59),
# Maria Bertram <- (Maria Bertram 10), (Miss Maria 37), (Mr. Edmund Bertram 58), (Thomas Bertram 59),
# Mary Crawford <- (Miss Crawford 4), (Mary Crawford 62), (Mrs. Crawford 75),
# Mrs. Norris <- (Mrs. Norris 34),
# Sir Thomas Bertram <- (Mr. Edmund Bertram 58), (Thomas Bertram 59),
# Tom Bertram <- (Mr. Edmund Bertram 58), (Thomas Bertram 59), (Tom Bertram 61),
# William Price <- (William Price 50),
# Yates <- (Mr. Yates 33),
#
# Book: White_Fang_Jack_London
# Beauty Smith <- (Beauty Smith 6),
# Collie <- (Collie 24),
# Gray Beaver <-
# Jim Hall <- (Jim Hall 11),
# Judge Scott <- (Mr. Scott 7),
# Kiche <- (Kiche 12),
# Lip-lip <- (Lip-lip 13),
# Mit-sah <- (Mit-sah 4),
# One Eye <-
# Weedon Scott <- (Mr. Scott 7), (Weedon Scott 26),
# White Fang <- (White Fang 15),
#
# Book: Major_Barbara_George_Bernard_Shaw
# Adolphus Cusins <- (Adolphus Cusins 13),
# Andrew Undershaft <- (Andrew Undershaft 2), (Barbara Undershaft 14),
# Barbara <- (Barbara Undershaft 14),
# Bill Walker <- (Bill Walker 1),
# Bilton <- (BILTON 10),
# Bronterre O'Brien Price <-
# Charles Lomax <- (Charles Lomax 36),
# Jenny Hill <- (Jenny Hill 3),
# Lady Britomart Undershaft <- (Lady Brit 9), (Barbara Undershaft 14), (Lady Britomart 27),
# Mrs. Baines <-
# Peter Shirley <- (Peter Shirley 5),
# Sarah Undershaft <- (SARAH 4), (Barbara Undershaft 14),
# Stephen Undershaft <- (Barbara Undershaft 14), (STEPHEN 33),
#
# Book: The_Portrait_of_a_Lady_Henry_James
# Caspar Goodwood <- (Mr. Caspar Goodwood 62),
# Countess Gemini <- (Countess 57),
# Edward Rosier <- (Mr. Edward Rosier 7),
# Gilbert Osmond <- (Mr. Gilbert Osmond 23), (Pansy Osmond 30),
# Henrietta Stackpole <- (Henrietta Stackpole 33),
# Isabel Archer <- (ISABEL ARCHER 45),
# Lord Warburton <- (LORD WARBURTON 34),
# Madame Merle <- (Madame Merle 17),
# Mr. Bantling <- (Mr. Bantling 12),
# Mrs. Touchett <- (Mrs. Touchett 16), (Mr. Ralph Touchett 41),
# Pansy Osmond <- (Mr. Gilbert Osmond 23), (Pansy Osmond 30),
# Ralph Touchett <- (Mr. Ralph Touchett 41),
#
# Book: Main_Street_Sinclair_Lewis
# Aunt Bessie <- (Aunt Bessie 161),
# Bea Sorenson <- (Bea Sorenson 150),
# Carol <- (Miss Carol Milford of St. Paul 14), (Carol Kennicott 152),
# Erik Valborg <- (Erik Valborg 85),
# Fern Mullins <- (FERN Mullins 115),
# Guy Pollock <- (Guy Pollock 173),
# Kennicott <- (Kennicotts 50), (Dr. Will Kennicott 78), (Carol Kennicott 152), (Doc Kennicott 157), (Mrs. Will Kennicott 193),
# Maud Dyer <- (Mrs. Dave Dyer 30), (Maud Dyer 186), (Ma Dawson 202),
# Miles Bjornstam <- (Miles Bjornstam 169),
# Mrs. Bogart <- (Mrs. Bogart 189),
# Raymond Wutherspoon <- (Ray 16), (Raymie Wutherspoon 42), (Raymond Wutherspoon 114),
# Uncle Whittier Smail <- (Uncle Whittier 43), (Uncle Whit 163),
# Vida Sherwin <- (Vida Sherwins 6), (Miss Vida Sherwin 136),
#
# Book: Othello_William_Shakespeare
# Bianca <- (Bianca 0),
# Brabanzio <-
# Clown <-
# Desdemona <- (Desdemona 8),
# Emilia <- (Emilia 6),
# Iago <-
# Michael Cassio <- (Michael Cassio 2),
# Othello <- (Othello 1),
# Roderigo <- (Roderigo 16),
#
# Book: Jude_the_Obscure_Thomas_Hardy
# Arabella Donn <- (Arabella Donn 55),
# Aunt Drusilla <- (Drusilla Fawley 30),
# Jude Fawley <- (Jude Fawley 27),
# Little Father Time (Little Jude) <- (Jude Fawley 27),
# Richard Phillotson <- (Mr. Phillotson 1), (Mrs. Richard Phillotson 34),
# Susanna Bridehead <- (SUSANNA FLORENCE MARY BRIDEHEAD 26),
#
# Book: Kidnapped_Robert_Louis_Stevenson
# Alan Breck Stewart <- (ALAN BRECK STEWART 38),
# Alexander Balfour <- (Mr. Alexander 12), (Mr. David Balfour 63),
# Captain Hoseason <- (Hoseason 52),
# David Balfour <- (Mr. David Balfour 63),
# Ebenezer Balfour <- (Mr. Ebenezer Balfour 47), (Mr. David Balfour 63),
# Henderland <- (Mr. Henderland 0),
# James of the Glens <- (JAMES STEWART 26), (James of the Glens 45),
# Mr. Campbell <- (COLIN CAMPBELL 3), (Mr. Campbell 65),
# Mr. Rankeillor <- (Mr. Rankeillor 34),
# Riach <- (Mr. Riach 51),
# Robin Oig <- (Robin Oig 49),
#
# Book: Measure_for_Measure_William_Shakespeare
# Barnadine <-
# Claudio <- (Signior Claudio 15),
# Elbow <-
# Escalus <- (Escalus 5),
# Isabella <- (Isabella 2), (Isabel 12),
# Juliet <- (Juliet 20),
# Lord Angelo <- (Lord Angelo 9),
# Lucio <- (Signior Lucio 14),
# Mariana <- (Mariana 18),
# Mistress Overdone <-
# Pompey <- (Pompey 23),
# Provost <-
# The Duke <- (Duke 0),
#
# Book: Titus_Andronicus_William_Shakespeare
# Aaron <- (Aaron 23),
# Bassianus <- (Prince Bassianus 10),
# Chiron <- (Chiron 26),
# Demetrius <- (Demetrius 13),
# Lavinia <- (LAVINIA 4),
# Lucius <- (Lucius 19),
# Marcus Andronicus <- (Marcus Andronicus 11),
# Saturninus <- (Saturninus 29),
# Tamora <- (Tamora 0),
# Titus Andronicus <- (Marcus Andronicus 11), (Lord Titus 16),
#
# Book: The_Picture_of_Dorian_Gray_Oscar_Wilde
# Alan Campbell <- (Alan Campbell 4),
# Basil Hallward <- (Basil Hallward 17),
# Dorian Gray <- (Mr. Dorian Gray 51),
# Duchess of Monmouth <-
# James Vane <- (James Vane 31),
# Lady Agatha <- (Lady Agatha 26),
# Lord Fermor <- (Lord Fermor 56),
# Lord Henry Wotton <- (Lord Henry Wotton 16),
# Mrs. Vane <- (Mrs. Vane 7),
# Sibyl Vane <- (Sibyl Vane 13),
# Victor <- (Victor 11),
# Victoria Wotton <- (Victor 11),
#
# Book: The_Turn_of_the_Screw_Henry_James
# Douglas <- (Douglas 8),
# Flora <- (Miss Flora 0),
# Luke <- (Luke 5),
# Miles <- (Miles 3),
# Miss Jessel <- (Miss Jessel 6),
# Mrs. Grose <- (Mrs. Grose 7),
# Peter Quint <- (Peter Quint 1),
# The Children’s Uncle <-
# The Governess <-
#
# Book: The_Trial_Franz_Kafka
# Assistant Manager <-
# Block <- (Mr. Block 14),
# Frau Grubach <-
# Fraulein Burstner <-
# Huld <- (Dr. Huld 13),
# Joseph K. <- (Mr. K. 12), (Josef K. 19),
# Leni <- (Leni 1),
# Titorelli <- (Titorelli 17),
# Uncle Karl <- (Uncle Karl 5),
# the Tradesman <-
#
# Book: Twelfth_Night_William_Shakespeare
# Antonio <- (Antonio 16),
# Feste <-
# Malvolio <- (Malvolio 26),
# Maria <- (Maria 12),
# Olivia <- (lady Olivia 23),
# Orsino <- (Orsino 13),
# Sebastian <- (Sebastian 21),
# Sir Andrew Aguecheek <- (Andrew Aguecheek 1),
# Sir Toby <- (TOBY BELCH 3),
# Viola <- (Viola 15),
#
# Book: An_Ideal_Husband_Oscar_Wilde
# Harold <-
# Lady Gertrude Chiltern <- (Robert Chiltern 11), (Gertrude Chiltern 20),
# Lady Markby <- (lady Markby 13),
# Lord Caversham <-
# Lord Goring <- (Lord Goring 17),
# Mabel Chiltern <- (Robert Chiltern 11), (MISS MABEL CHILTERN 24),
# Mason <- (Mason 27),
# Mrs. Cheveley <- (Mrs. Cheveley 6),
# Phipps <- (Phipps 36),
# Sir Robert Chiltern <- (Robert Chiltern 11),
#
# Book: A_Tale_of_Two_Cities_Charles_Dickens
# Charles Darnay <- (Mr. Charles Darnay 19),
# Doctor Manette <- (Miss Manette 37),
# Gabelle <- (Monsieur Gabelle 18),
# Jarvis Lorry <- (Mr. Jarvis Lorry 52),
# Lucie Manette <- (Miss Manette 37), (Lucie Manette 56), (Miss Lucie 59),
# Madame Defarge <- (Madame Defarge 0), (Monsieur Defarge 42),
# Marquis Evrémonde <- (Monsieur the Marquis 20),
# Miss Pross <- (Miss Pross 23),
# Monsieur Defarge <- (Monsieur the Marquis 20), (Monsieur Defarge 42),
# Mr. Stryver <- (Mr. Stryver 7),
# Sydney Carton <- (Sydney Carton 3), (Mr. Carton 49),
#
# Book: The_Tempest_William_Shakespeare
# Alonso <- (Alonso 3),
# Antonio <- (Antonio 11),
# Ariel <- (Ariel 22),
# Caliban <- (Caliban 13),
# Ferdinand <- (Ferdinand 0),
# Gonzalo <- (Gonzalo 9),
# Miranda <- (Miranda 15),
# Prospero <- (Prospero 10),
# Sebastian <- (Sebastian 19),
# Trinculo & Stephano <- (Trinculo 7), (Stephano 14),
#
# Book: The_Scarlet_Letter_Nathaniel_Hawthorne
# Governor Bellingham <-
# Hester Prynne <- (Hester Prynne 30),
# Mistress Hibbins <- (Hibbins 1),
# Narrator <-
# Pearl <- (Pearl 14),
# Reverend Arthur Dimmesdale <- (Arthur Dimmesdale 7), (Mr. Dimmesdale 24),
# Reverend Mr. John Wilson <- (John Wilson 2), (Mr. Wilson 5),
# Roger Chillingworth <- (Roger Chillingworth 9),
#
# Book: Maggie:_A_Girl_of_the_Streets_Stephen_Crane
# Billie <- (Billie 10),
# Father <-
# Jimmie <- (Jimmie 5), (Jim 7),
# Maggie <- (Maggie 12),
# Mary <- (Mary 6),
# Miss Smith <-
# Nellie <- (Nell 2), (Nellie 3),
# Pete <- (Pete 9),
# The old woman <-
# Tommie <- (Tommie 11),
#
# Book: The_Two_Gentlemen_of_Verona_William_Shakespeare
# Antonio <-
# Crab <-
# Duke of Milan <-
# Julia <- (Madam Julia 2),
# Launce <- (Launce 4),
# Lucetta <- (Lucetta 16),
# Outlaws <-
# Proteus <-
# Silvia <- (Madam Silvia 9), (lady Silvia 11),
# Sir Eglamour <- (Eglamour 13),
# Speed <-
# Thurio <- (Thurio 10),
# Valentine <- (Valentine 5),
#
# Book: Macbeth_William_Shakespeare
# Banquo <- (-- Banquo 66),
# Fleance <- (Fleance 58),
# Hecate <-
# King Duncan <- (DUNCAN 72),
# Lady Macbeth <- (-- Secourez lady Macbeth 50),
# Lady Macduff <- (-- Macduff 20), (Lady Macduff 73),
# Macbeth <- (Entre Macbeth 22), (-- Secourez lady Macbeth 50),
# Macduff <- (Rentre Macduff 13), (-- Macduff 20), (Lady Macduff 73),
# Malcolm <- (-- Malcolm 2),
# Porter <-
# The Three Witches <-
#
# Book: Pygmalion_George_Bernard_Shaw
# Alfred Doolittle <- (Alfred Doolittle 7), (Eliza Doolittle 27),
# Colonel Pickering <- (Pick 9), (Pickering 18),
# Eliza Doolittle <- (Eliza Doolittle 27),
# Freddy Eynsford Hill <- (FREDDY 4),
# Mrs. Higgins <- (Mrs. Higgins 25),
# Professor Henry Higgins <- (Mrs. Higgins 25), (Henry Higgins 28),
#
# Book: The_Mayor_of_Casterbridge_Thomas_Hardy
# Abel Whittle <- (Abel Whittle 30),
# Benjamin Grower <- (Mr. Grower 51),
# Christopher Coney <- (Christopher Coney 60),
# Donald Farfrae <- (Donald Farfrae 37),
# Elizabeth-Jane Newson <- (Elizabeth-Jane Newson 42), (Elizabeth 43),
# Joshua Jopp <- (Jopp 17), (Joshua 34),
# Lucetta Templeman <- (LUCETTA 19), (Miss Templeman 31),
# Michael Henchard <- (MR. MICHAEL HENCHARD 39),
# Mother Cuxsom <- (Mother Cuxsom 46),
# Nance Mockridge <- (Nance Mockridge 11),
# Newson <- (Mrs. Henchard-Newson 6), (Richard Newson 7), (Mrs. Newson 8), (Miss Newson 22), (Elizabeth-Jane Newson 42),
# Susan Henchard <- (Susan Henchard 24), (MR. MICHAEL HENCHARD 39),
#
# Book: Love's_Labours_Lost_William_Shakespeare
# Berowne <- (Monsieur Berowne 7), (Lord Berowne 19),
# Boyet <- (BOYET 18),
# Costard <- (Costard 15),
# Don Armado <- (Don Adriano de Armado 12),
# Dumaine <- (Judas I am - DUMAIN 11),
# Jaquenetta <- (JAQUENETTA 24),
# Katherine <-
# King of Navarre <-
# Longaville <- (Lord Longaville 6),
# Maria <- (Maria 16),
# Mote <-
# Princess of France <-
# Rosaline <- (Lady Rosaline 1),
#
# Book: Much_Ado_About_Nothing_William_Shakespeare
# Antonio <- (-LSB- Antonio 1),
# Beatrice <- (Lady Beatrice 22),
# Benedick <- (Bene 7), (Signior Benedick 17),
# Borachio <- (Borachio 6),
# Claudio <- (Claud 0), (Claudio 18),
# Conrad <- (Conrade 2),
# Don John <- (Don Pedro 20), (Don John 25),
# Don Pedro <- (Don Pedro 20),
# Hero <-
# Leonato <- (Leon 16), (Signior Leonato 21),
# Margaret <- (Margaret 8), (Marg 24),
#
# Book: The_Secret_Garden_Frances_Hodgson_Burnett
# Archibald Craven <- (Dr. Craven 5), (Mr. Archibald Craven 9),
# Ben Weatherstaff <- (Ben Weatherstaff 33),
# Colin Craven <- (Dr. Craven 5), (Mr. Archibald Craven 9), (Mester Colin 14),
# Dickon Sowerby <- (Dickon 15),
# Dr. Craven <- (Dr. Craven 5), (Mr. Archibald Craven 9),
# Lilias Craven <- (Dr. Craven 5), (Mr. Archibald Craven 9),
# Martha Sowerby <- (Martha 4),
# Mary Lennox <- (Mary Lennox 28),
# Mrs. Medlock <- (Mrs. Medlock 24),
# Susan Sowerby <- (Susan Sowerby 1),
#
# Book: Treasure_Island_Robert_Louis_Stevenson
# Ben Gunn <- (Ben Gunn 4),
# Billy Bones <- (Bill 14), (Billy Bones 43),
# Black Dog <- (Black Dog 26),
# Captain Smollett <- (Mr. Smollett 48),
# Dr. Livesey <- (Dr. Livesey 22),
# Jim Hawkins <- (JIM HAWKINS 24),
# Long John Silver <- (Long John Silver 35),
# Pew <-
# Squire Trelawney <- (Squire 1), (Mr. Trelawney 29),
# Tom Redruth <- (Tom Redruth 34),
#
# Book: Siddhartha_Hermann_Hesse
# Gotama <-
# Govinda <- (Govinda 126),
# Kamala <- (Liebe Kamala 203),
# Kamaswami <-
# Siddhartha <- (Samana Siddhartha 26), (Siddhartha bei den Samanas 102), (Siddharthas Seele 108), (da Siddhartha 148),
# Siddhartha’s Father <- (Samana Siddhartha 26), (Siddhartha bei den Samanas 102),
# The Samanas <- (Samana Siddhartha 26), (Siddhartha bei den Samanas 102),
# Vasudeva <- (Vasudeva 132),
# Young Siddhartha <- (Samana Siddhartha 26), (Siddhartha bei den Samanas 102),
#
# Book: The_Return_of_the_Native_Thomas_Hardy
# Captain Vye <- (Eustacia Vye 15), (Miss Vye 19),
# Charley <- (Charley 4),
# Christian Cantle <- (Christian Cantle 16),
# Clym Yeobright <- (Clym Yeobright 26), (THOMASIN YEOBRIGHT 38), (Mrs. Yeobright 45),
# Damon Wildeve <- (MR. WILDEVE 6), (Damon 29),
# Diggory Venn <- (Mrs. Venn 0), (Diggory Venn 40),
# Eustacia Vye <- (Miss Eustacia 14), (Eustacia Vye 15), (Miss Vye 19),
# Mrs. Yeobright <- (THOMASIN YEOBRIGHT 38), (Mrs. Yeobright 45),
# Thomasin Yeobright <- (THOMASIN YEOBRIGHT 38), (Mrs. Yeobright 45),
#
# Total chars annotated: 1306.
# Total chars from annotations in books 1073.
# Not found: 233.
# Multiple chars corresponding: 507
# [{'count': 1, 'book': 'Don_Quixote_Miguel_de_Cervantes', 'char': 'Altisidora'}, {'count': 3, 'book': 'Don_Quixote_Miguel_de_Cervantes', 'char': 'Don Quixote'}, {'count': 4, 'book': 'The_Count_of_Monte_Cristo_Alexandre_Dumas', 'char': 'Monsieur Morrel'}, {'count': 6, 'book': 'Henry_VI_Part_3_William_Shakespeare', 'char': 'Edward'}]

# %%
# probable people https://github.com/datamade/probablepeople
